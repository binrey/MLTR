# %%
from real_trading import plot_fig
import pickle
from pathlib import Path
import mplfinance as mpf
import matplotlib.pyplot as plt

# %reload_ext autoreload
# %autoreload 2

# %%
log = pickle.load(open("./real_trading/ETHUSDT-M1/2024-02-11 10-52-25.pickle", "rb"))

# %%
fig = plot_fig(log["hist"], log["lines"], t=log["time"], side="Sell")#, save_path=Path("./real_trading/"))

# %%
fig.savefig("t.png", bbox_inches='tight', pad_inches=0.2)
